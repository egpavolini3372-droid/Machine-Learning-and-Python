# %%
# Tu misión para completar el desafío:
# El programa debe hacer esto:
# Genera un número aleatorio entre 1 y 10. El usuario tiene 3 intentos para adivinarlo. Indica si el número es mayor o menor.
# hint: Usa `import random` y `random.randint(1, 10)`. Usa un bucle `for` o `while`.
import numpy as np
import random

num_secreto = random.randint(1,10)

contador = 0

for i in range(5): # Cambia este número para modificar la cantidad de intentos
  intento = int(input("Adivina el numero (del 1 al 10): "))

  if intento == num_secreto:
    print(f"Felicidades, adivinaste el numero secreto {num_secreto} en el intento numero {contador + 1})")
    break
  elif intento < num_secreto:
    contador = contador + 1
    print("El numero es mayor")
  elif intento > num_secreto:
     contador = contador + 1
     print("El numero es menor")
  if contador == 5: # También actualiza este número si cambias el rango
    print(f"Lo siento, no adivinaste el numero secreto. El numero secreto era {num_secreto}")
# Out:
# Adivina el numero (del 1 al 10): 5
# El numero es menor
# Adivina el numero (del 1 al 10): 7
# El numero es menor
# Adivina el numero (del 1 al 10): 2
# El numero es mayor
# Adivina el numero (del 1 al 10): 3
# El numero es mayor
# Adivina el numero (del 1 al 10): 4
# Felicidades, adivinaste el numero secreto 4 en el intento numero 5)
