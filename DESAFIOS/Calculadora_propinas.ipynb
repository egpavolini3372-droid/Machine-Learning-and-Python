# %%
total = float(input("¿Cuánto fue la cuenta? $"))

propina_15 = total * 0.15
propina_18 = total * 0.18
propina_20 = total * 0.20

print(f"Propina 15%: ${propina_15:.2f}")
print(f"Propina 18%: ${propina_18:.2f}")
print(f"Propina 20%: ${propina_20:.2f}")
# Out:
# ¿Cuánto fue la cuenta? $100
# Propina 15%: $15.00
# Propina 18%: $18.00
# Propina 20%: $20.00
