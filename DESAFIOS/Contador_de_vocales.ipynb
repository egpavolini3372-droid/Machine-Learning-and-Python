# %%
respuesta = input("Escribe una frase: ").lower()
contador = 0
vocales_encontradas = []

for letra in respuesta:
    if letra in "aeiou":
        contador += 1
        vocales_encontradas.append(letra)

print(f"Vocales encontradas: {contador}")
print(f"Cuáles: {vocales_encontradas}")
