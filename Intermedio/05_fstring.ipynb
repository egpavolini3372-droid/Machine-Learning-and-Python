# %%
name = "Ana"
year = 2020
text = f"Hola {name}"
print(text)
text_2 = "Hola"

text_format = "Hola {}".format(name)
print(text_format)

text_suma = f"Hol {name}, tu edad es: {2025 - year} años"
print(text_suma)

text_func = f"Hola {name.upper()}"
print(text_func)

edad = 18
text_if = f"Hola {name}, eres {"mayor " if edad >=18 else "menor "}de edad "
print(text_if)
# Out:
# Hola Ana
# Hola Ana
# Hol Ana, tu edad es: 5 años
# Hola ANA
# Hola Ana, eres mayor de edad
