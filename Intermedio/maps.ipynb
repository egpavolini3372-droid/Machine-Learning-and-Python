# %%
numeros = list(range(1,6))
cuadrados = []
print(numeros)

for num in numeros:
  cuadrados.append(num **2)

print(cuadrados)

def cuadrado(num):
  return num **2

cuadrados_map = list(map(cuadrado, numeros))

print(list(cuadrados_map))

def get_reading_time(article: dict)-> dict:
  minutes = len(article["content"]// 200 + 1)
  article["reading_time"] = minutes
  return article
# Out:
# [1, 2, 3, 4, 5]
# [1, 4, 9, 16, 25]
# [1, 4, 9, 16, 25]
