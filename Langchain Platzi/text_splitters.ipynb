# %% [markdown]
# # Splitters

# %%
# %pip install -qU langchain-text-splitters

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/MyDrive/PYTHON/Langchain Platzi/example-1.txt') as f:
  state_of_the_union = f.read()

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=10,
    chunk_overlap=2,
    length_function=len,
    is_separator_regex=False,
)

# %%
text = text_splitter.create_documents([state_of_the_union])

# %%
text
# Out:
# [Document(metadata={}, page_content='Lorem'),
#  Document(metadata={}, page_content='ipsum'),
#  Document(metadata={}, page_content='dolor sit'),
#  Document(metadata={}, page_content='amet,'),
#  Document(metadata={}, page_content='consectet'),
#  Document(metadata={}, page_content='etur'),
#  Document(metadata={}, page_content='adipiscin'),
#  Document(metadata={}, page_content='ing'),
#  Document(metadata={}, page_content='elit. Sed'),
#  Document(metadata={}, page_content='do'),
#  Document(metadata={}, page_content='eiusmod'),
#  Document(metadata={}, page_content='tempor'),
#  Document(metadata={}, page_content='incididun'),
#  Document(metadata={}, page_content='unt'),
#  Document(metadata={}, page_content='ut labore'),
#  Document(metadata={}, page_content='et dolore'),
#  Document(metadata={}, page_content='magna'),
#  Document(metadata={}, page_content='aliqua.'),
#  Document(metadata={}, page_content='Ut enim'),
#  Document(metadata={}, page_content='ad minim'),
#  Document(metadata={}, page_content='veniam,'),
#  Document(metadata={}, page_content='quis'),
#  Document(metadata={}, page_content='nostrud'),
#  Document(metadata={}, page_content='exercitat'),
#  Document(metadata={}, page_content='ation'),
#  Document(metadata={}, page_content='ullamco'),
#  Document(metadata={}, page_content='laboris'),
#  Document(metadata={}, page_content='nisi ut'),
#  Document(metadata={}, page_content='aliquip'),
#  Document(metadata={}, page_content='ex ea'),
#  Document(metadata={}, page_content='commodo'),
#  Document(metadata={}, page_content='consequat'),
#  Document(metadata={}, page_content='at.'),
#  Document(metadata={}, page_content='Duis aute'),
#  Document(metadata={}, page_content='irure'),
#  Document(metadata={}, page_content='dolor in'),
#  Document(metadata={}, page_content='reprehend'),
#  Document(metadata={}, page_content='nderit'),
#  Document(metadata={}, page_content='in'),
#  Document(metadata={}, page_content='voluptate'),
#  Document(metadata={}, page_content='velit'),
#  Document(metadata={}, page_content='esse'),
#  Document(metadata={}, page_content='cillum'),
#  Document(metadata={}, page_content='dolore eu'),
#  Document(metadata={}, page_content='fugiat'),
#  Document(metadata={}, page_content='nulla'),
#  Document(metadata={}, page_content='pariatur.'),
#  Document(metadata={}, page_content='Excepteur'),
#  Document(metadata={}, page_content='sint'),
#  Document(metadata={}, page_content='occaecat'),
#  Document(metadata={}, page_content='cupidatat'),
#  Document(metadata={}, page_content='non'),
#  Document(metadata={}, page_content='proident,'),
#  Document(metadata={}, page_content='sunt in'),
#  Document(metadata={}, page_content='culpa qui'),
#  Document(metadata={}, page_content='officia'),
#  Document(metadata={}, page_content='deserunt'),
#  Document(metadata={}, page_content='mollit'),
#  Document(metadata={}, page_content='anim id'),
#  Document(metadata={}, page_content='est'),
#  Document(metadata={}, page_content='laborum.')]

# %%
text[0]
# Out:
# Document(metadata={}, page_content='Lorem')

# %%
text[1]
# Out:
# Document(metadata={}, page_content='ipsum')
