# %%
import numpy as np
import pandas as pd
# CSV
path = '/content/LBase-de-datos-Cuestionario-Sumativo-M4.xlsx'
data = pd.read_excel(path)

# EXCEL
date_excel = pd.read_excel(path)

#JSON
#data_json = pd.read_json(path)

print(data.head())
print(type(data))
# Out:
#     Año  Población, total  Crecimiento de la población (% anual)  \
# 0  1980        27737905.0                               2.276776
# 1  1981        28375995.0                               2.274365
# 2  1982        29027158.0                               2.268833
# 3  1983        29687096.0                               2.248060
# 4  1984        30350082.0                               2.208675
#
#    Población de 65 años de edad y más (% del total)  \
# 0                                          3.744526
# 1                                          3.772840
# 2                                          3.800465
# 3                                          3.828761
# 4                                          3.859182
#
#    Población entre 15 y 64 años de edad (% del total)  \
# 0                                          55.655771
# 1                                          56.086498
# 2                                          56.642886
# ...

# %%
summary = data.describe()
print(summary)
# Out:
#        Población, total  Crecimiento de la población (% anual)  \
# count      3.500000e+01                              35.000000
# mean       3.833527e+07                               1.619467
# std        6.123497e+06                               0.422945
# min        2.773790e+07                               0.944004
# 25%        3.329999e+07                               1.284253
# 50%        3.864541e+07                               1.555213
# 75%        4.356069e+07                               1.971658
# max        4.779139e+07                               2.276776
#
#        Población de 65 años de edad y más (% del total)  \
# count                                         35.000000
# mean                                           4.742600
# std                                            0.839272
# min                                            3.744526
# 25%                                            4.073821
# 50%                                            4.528274
# ...
