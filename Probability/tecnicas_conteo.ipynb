# %%
import math
import numpy as np
import pandas as pd
# CSV
path = '/content/_BD-Fuga-Clientes-FINAL.xlsx'
data = pd.read_excel(path)




# Calculate 25! (25 * 24 * 23 *... 2 * 1)
fact_25 = math.factorial(25)
fact_21  = math.factorial(21)
resultado = fact_25 / fact_21
print(resultado)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_11655/3171236549.py in <cell line: 0>()
#       4 # CSV
#       5 path = '/content/_BD-Fuga-Clientes-FINAL.xlsx'
# ----> 6 data = pd.read_excel(path)
#       7
#       8
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
# Punto 1

C_45_6 = math.comb(45, 6)
P = 1 / C_45_6
print(C_45_6)
print(P)
# Out:
# 8145060
# 1.2277380399898834e-07

# %%
#Punto 2

n = 25
k = 4
n_l = 10
n_t = 15
k_2 = 3
k_3 = 1
k_4 = 0




C_15_3 = math.comb(n_t, k_2)
C_10_1 = math.comb(n_l, k_3)
C_25_4 = math.comb(n, k)
C_15_4 = math.comb(n_t, k)
C_10_0 = math.comb(n_l, k_4)


P_X_3 = C_15_3* C_10_1 / C_25_4
P_X_4 = C_15_4* C_10_0 / C_25_4
res1 = P_X_3 + P_X_4
print(res1)
# Out:
# 0.4675889328063241

# %%
# Punto 3

fact_7 = math.factorial(7)
fact_8  = math.factorial(8)
res2= fact_7 / fact_8
print(res2)
# Out:
# 0.125

# %%
print(data.head())
print(type(data))
print(data.info)
# Out:
#   ID cliente  Edad en la red  Gasto total al mes  Gasto en SMS por SMS  \
# 0    ADF1330           29.60             878.650                  8.76
# 1    ADF1331            4.00             878.720                294.00
# 2    ADF1345          126.97             898.490                 15.75
# 3    ADF1349            3.60             904.322                155.66
# 4    ADF1363           26.50             920.142                  0.00
#
#    Gasto de datos por SMS  Consumo  total de datos  Velocidad promedio carga  \
# 0                   47.50              115805.2080                  5.756665
# 1                    6.25              696816.2705                  8.864864
# 2                    0.00              464885.6963                  7.367746
# 3                   80.00              799300.8506                  9.776392
# 4                    0.00               47665.3779                  5.072836
#
#    Velocidad promedio descarga  Llamadas únicas  Llamadas caídas  \
# ...

# %%
data['match'] = (data['Llamadas caídas'] >= 5) & (data['Llamas por quejas al mes'] >= 3)
print(data['match'])
n_clientes_mamados = data['match'].sum()
print(n_clientes_mamados)
P_cliente_mamado = n_clientes_mamados / 289
print(P_cliente_mamado)
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 286     True
# 287     True
# 288     True
# 289    False
# 290    False
# Name: match, Length: 291, dtype: bool
# 83
# 0.28719723183391005

# %%
customer_cancel= data["Cancelación suscripción"].sum()
n = len(data)
print(n)
print(customer_cancel)
P_cancel = customer_cancel/n
print(P_cancel)
# Out:
# 291
# 28.0
# 0.09621993127147767

# %%
count = 0
for i in data["Competidor favorito"]:
  if i == "Mango":
    count +=1
print(count)
P_Mango = count / n
print(P_Mango)
# Out:
# 33
# 0.1134020618556701

# %%
data['match_2'] = (data['Cancelación suscripción'] == 1) & (data['Tipo de red preferida'] == "3G")
n_clientes_3G_cancel = data['match_2'].sum()

print(n_clientes_3G_cancel)
P3 = n_clientes_3G_cancel/customer_cancel
print(P3)
# Out:
# 8
# 0.2857142857142857

# %%
P_instagram = (121)/342
print(P_instagram)

P_instagram_25 =(121-54-37)/342
print(P_instagram_25)

P_facebook_20 = 55/135
print(P_facebook_20)
# Out:
# 0.3538011695906433
# 0.08771929824561403
# 0.4074074074074074

# %%
C_4_2 = math.comb(4, 2)
C_6_2 = math.comb(6, 2)
C_10_4 = math.comb(10, 4)
C_4_3 = math.comb(4, 3)
C_6_1 = math.comb(6, 1)
C_4_4 = math.comb(4, 4)
C_6_0 = math.comb(6, 0)

P1 =C_4_2*C_6_2/C_10_4
P2 =C_4_3*C_6_1/C_10_4
P3 =C_4_4*C_6_0/C_10_4

P = P1 + P2 + P3

print(P)
# Out:
# 0.5476190476190476

# %%
P_def = 0.3*0.1 + 0.5*0.15 + 0.2*0.12
P_def_B = 0.5*0.15/P_def
print(P_def_B)
print(P_def)
# Out:
# 0.5813953488372092
# 0.129

# %%
P_NV_S =5/35/(5/35+7/30 +1/18)
print(P_NV_S)
# Out:
# 0.33088235294117646
