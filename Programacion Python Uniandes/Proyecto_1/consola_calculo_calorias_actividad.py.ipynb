# %%
# %%writefile consola_calculo_calorias_actividad.py
def calcular_calorias_en_actividad(peso, altura, edad, valor_genero,valor_actividad):

  peso = float(input("ingrese el peso de la persona (en kilogramos):"))
  altura = float(input("ingrese la altura de la persona (en metros):"))
  edad = float(input("ingrese la edad de la persona (en años):"))
  valor_genero = float(input("en caso de ser masculino debe ser 5 y en caso de ser femenino debe ser -161:"))


  TBM2 = calcular_calorias_en_reposo(peso,altura,edad,valor_genero)*valor_actividad
  return TBM2
# Out:
# Writing consola_calculo_calorias_actividad.py
