# %%
# %%writefile consola_calculo_imc.py
# import imc_calculator
# Call the function from the imported module; it will now prompt for input
def calcular_IMC(peso,altura):
  peso = float(input("ingrese el peso de la persona (en kilogramos):"))
  altura = float(input("ingrese la altura de la persona (en metros):"))
  IMC = 0
  IMC = peso/ (altura**2)

  return IMC
# Out:
# Writing consola_calculo_imc.py

# %%
A = calcular_IMC(1,1)
print(A)
# Out:
# ingrese el peso de la persona (en kilogramos):82
# ingrese la altura de la persona (en metros):1.77
# 26.173832551310287
