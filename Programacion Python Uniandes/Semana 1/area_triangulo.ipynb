# %%
import math

def area_triangulo(s1, s2, s3):
    s = (s1 + s2 + s3) / 2
    area = math.sqrt(s * (s - s1) * (s - s2) * (s - s3))
    return round(area, 1)

print(area_triangulo(3, 4, 5))
# Out:
# 6.0
