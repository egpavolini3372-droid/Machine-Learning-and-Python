# %%
def cual_mayor(a:int,b:int,c:int,d:int):
  if (a>=b) and (a>=c) and (a>=d):
      res=a
  elif (b>=a) and (b>=c) and (b>=d):
      res=b
  elif (c>=a) and (c>=b) and (c>=d):
      res=c
  else:
    res=d
  return res

def cual_mayor_v2(a:int,b:int,c:int,d:int):
  res=max(a,b,c,d)
  return res

def cual_mayor_v3(a:int,b:int,c:int,d:int):
  mayor = a
  if (b>mayor):
    mayor=b
  if (c>mayor):
    mayor = c
  if (d>mayor):
    mayor = d
  return mayor


a=int(input("Ingrese el primer numero: "))
b=int(input("Ingrese el segundo numero: "))
c=int(input("Ingrese el tercer numero: "))
d=int(input("Ingrese el cuarto numero: "))

cm = cual_mayor(a,b,c,d)
print(cm)

cm2 = cual_mayor_v2(a,b,c,d)
print(cm2)

cm3 = cual_mayor_v3(a,b,c,d)
print(cm2)
# Out:
# Ingrese el primer numero: 1
# Ingrese el segundo numero: 2
# Ingrese el tercer numero: 3
# Ingrese el cuarto numero: 1
# 3
# 3
# 3
