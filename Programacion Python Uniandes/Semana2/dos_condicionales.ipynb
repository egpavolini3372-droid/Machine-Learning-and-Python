# %%
def positivo_and_un_digito(x:int)->bool:
   "Funcion que recibe como parametro un numeor entero y devuelve verdadero si es un entero positivo y falso de lo contrarrio "
   respuesta= False
   if x<10 and x>0:
       respuesta = True
   return respuesta

numero = int(input("Ingrese un numero: "))
print(positivo_and_un_digito(numero))

def es_divisible(n:int,d:int)->int:

  if d==0:
    resp = 0
  elif n%(2*d)==0:
    resp= 2
  elif n%d == 0:
   resp = 1
  else:
    resp = 0
  return resp

n = int(input("Ingrese el dividendo: "))
d = int(input("Ingrese el divisor: "))
u = es_divisible(n,d)
print(u)
# Out:
# Ingrese un numero: 1
# True
# Ingrese el dividendo: 2
# Ingrese el divisor: 2
# 1
