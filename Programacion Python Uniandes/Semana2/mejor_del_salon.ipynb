# %%
def mejor_del_salon(estudiante1:dict,estudiante2:dict,estudiante3:dict,estudiante4:dict,estudiante5:dict):
  prom1 = (estudiante1["matematicas"]+estudiante1["español"]+estudiante1["ciencias"]+estudiante1["literatura"]+estudiante1["arte"])/5
  prom2 = (estudiante2["matematicas"]+estudiante2["español"]+estudiante2["ciencias"]+estudiante2["literatura"]+estudiante2["arte"])/5
  prom3 = (estudiante3["matematicas"]+estudiante3["español"]+estudiante3["ciencias"]+estudiante3["literatura"]+estudiante3["arte"])/5
  prom4 = (estudiante4["matematicas"]+estudiante4["español"]+estudiante4["ciencias"]+estudiante4["literatura"]+estudiante4["arte"])/5
  prom5 = (estudiante5["matematicas"]+estudiante5["español"]+estudiante5["ciencias"]+estudiante5["literatura"]+estudiante5["arte"])/5

  mejor =estudiante1["nombre"]
  prom = prom1

  if prom2 > prom1 and prom2 > prom3 and prom2 > prom4 and prom2 > prom5:
    mejor = estudiante2["nombre"]
    prom=prom2
  if prom3 > prom1 and prom3 > prom2 and prom3 > prom4 and prom3 > prom5:
    prom=prom3
    mejor = estudiante3["nombre"]
  if prom4 > prom1 and prom4 > prom2 and prom4 > prom3 and prom4 > prom5:
    mejor = estudiante4["nombre"]
    prom=prom4
  if prom5 > prom1 and prom5 > prom4 and prom5 > prom3 and prom5 > prom2:
    mejor = estudiante5["nombre"]
    prom=prom5


  return mejor, prom1, prom2,prom3,prom4,prom5

estudiante1 = {'nombre': 'pablo', 'matematicas': 3.4, 'español': 5.0, 'ciencias': 2.9, 'literatura': 4.2, 'arte': 3.2}
estudiante2 = {'nombre': 'andres', 'matematicas': 2.1, 'español': 5.0, 'ciencias': 3.0, 'literatura': 4.1, 'arte': 3.5}
estudiante3 = {'nombre': 'daniela', 'matematicas': 5.0, 'español': 4.2, 'ciencias': 4.4, 'literatura': 3.5, 'arte': 4.7}
estudiante4 = {'nombre': 'maria', 'matematicas': 3.2, 'español': 3.7, 'ciencias': 3.1, 'literatura': 4.7, 'arte': 3.4}
estudiante5 = {'nombre': 'pedro', 'matematicas': 5.0, 'español': 4.2, 'ciencias': 4.4, 'literatura': 3.5, 'arte': 4.7}
print(mejor_del_salon(estudiante1,estudiante2,estudiante3,estudiante4,estudiante5))
# Out:
# ('pablo', 3.7399999999999998, 3.54, 4.36, 3.6199999999999997, 4.36)

# %%
def mejor_del_salon(estudiante1:dict,estudiante2:dict,estudiante3:dict,estudiante4:dict,estudiante5:dict):
  prom1 = (estudiante1["matematicas"]+estudiante1["español"]+estudiante1["ciencias"]+estudiante1["literatura"]+estudiante1["arte"])/5
  prom2 = (estudiante2["matematicas"]+estudiante2["español"]+estudiante2["ciencias"]+estudiante2["literatura"]+estudiante2["arte"])/5
  prom3 = (estudiante3["matematicas"]+estudiante3["español"]+estudiante3["ciencias"]+estudiante3["literatura"]+estudiante3["arte"])/5
  prom4 = (estudiante4["matematicas"]+estudiante4["español"]+estudiante4["ciencias"]+estudiante4["literatura"]+estudiante4["arte"])/5
  prom5 = (estudiante5["matematicas"]+estudiante5["español"]+estudiante5["ciencias"]+estudiante5["literatura"]+estudiante5["arte"])/5

  # Store all students and their average scores in a dictionary for easy comparison
  student_averages = {
      estudiante1["nombre"]: prom1,
      estudiante2["nombre"]: prom2,
      estudiante3["nombre"]: prom3,
      estudiante4["nombre"]: prom4,
      estudiante5["nombre"]: prom5
  }

  # Find the student with the highest average score
  mejor = max(student_averages, key=student_averages.get)

  return mejor, student_averages

estudiante1 = {'nombre': 'pablo', 'matematicas': 3.4, 'español': 5.0, 'ciencias': 2.9, 'literatura': 4.2, 'arte': 3.2}
estudiante2 = {'nombre': 'andres', 'matematicas': 2.1, 'español': 5.0, 'ciencias': 3.0, 'literatura': 4.1, 'arte': 3.5}
estudiante3 = {'nombre': 'daniela', 'matematicas': 1.0, 'español': 4.2, 'ciencias': 4.4, 'literatura': 3.5, 'arte': 4.7}
estudiante4 = {'nombre': 'maria', 'matematicas': 3.2, 'español': 3.7, 'ciencias': 3.1, 'literatura': 4.7, 'arte': 3.4}
estudiante5 = {'nombre': 'pedro', 'matematicas': 4.7, 'español': 4.2, 'ciencias': 4.3, 'literatura': 2.5, 'arte': 4.2}
print(mejor_del_salon(estudiante1,estudiante2,estudiante3,estudiante4,estudiante5))
# Out:
# ('pedro', {'pablo': 3.7399999999999998, 'andres': 3.54, 'daniela': 3.56, 'maria': 3.6199999999999997, 'pedro': 3.9799999999999995})

# %%
def mejor_de_cada_curso(estudiante1:dict,estudiante2:dict,estudiante3:dict,estudiante4:dict,estudiante5:dict):

  # Store all students and their average scores in a dictionary for easy comparison
  student_math = {
      estudiante1["nombre"]:estudiante1["matematicas"],
      estudiante2["nombre"]: estudiante2["matematicas"],
      estudiante3["nombre"]: estudiante3["matematicas"],
      estudiante4["nombre"]: estudiante4["matematicas"],
      estudiante5["nombre"]: estudiante5["matematicas"],
  }
  dict_math_sorted = dict(sorted(student_math.items(), key=lambda item: item[1], reverse=True))
  # Store all students and their average scores in Spanish in a dictionary for easy comparison
  student_spa = {
      estudiante1["nombre"]:estudiante1["español"],
      estudiante2["nombre"]: estudiante2["español"],
      estudiante3["nombre"]: estudiante3["español"],
      estudiante4["nombre"]: estudiante4["español"],
      estudiante5["nombre"]: estudiante5["español"],
    }
  dict_spa_sorted =  dict(sorted(student_spa.items(), key=lambda item: item[1], reverse=True))
   # Store all students and their average scores in Spanish in a dictionary for easy comparison
  student_sci = {
      estudiante1["nombre"]:estudiante1["ciencias"],
      estudiante2["nombre"]: estudiante2["ciencias"],
      estudiante3["nombre"]: estudiante3["ciencias"],
      estudiante4["nombre"]: estudiante4["ciencias"],
      estudiante5["nombre"]: estudiante5["ciencias"],
    }
  dict_sci_sorted =  dict(sorted(student_sci.items(), key=lambda item: item[1], reverse=True))
     # Store all students and their average scores in Spanish in a dictionary for easy comparison
  student_lit = {
      estudiante1["nombre"]:estudiante1["literatura"],
      estudiante2["nombre"]: estudiante2["literatura"],
      estudiante3["nombre"]: estudiante3["literatura"],
      estudiante4["nombre"]: estudiante4["literatura"],
      estudiante5["nombre"]: estudiante5["literatura"],
    }
  dict_lit_sorted =  dict(sorted(student_lit.items(), key=lambda item: item[1], reverse=True))
      # Store all students and their average scores in Spanish in a dictionary for easy comparison
  student_art = {
      estudiante1["nombre"]:estudiante1['arte'],
      estudiante2["nombre"]: estudiante2['arte'],
      estudiante3["nombre"]: estudiante3['arte'],
      estudiante4["nombre"]: estudiante4['arte'],
      estudiante5["nombre"]: estudiante5['arte'],
    }
  dict_art_sorted =  dict(sorted(student_art.items(), key=lambda item: item[1], reverse=True))

  max_math=max(dict_math_sorted, key=dict_math_sorted.get)
  max_spa=max(dict_spa_sorted, key=dict_spa_sorted.get)
  max_sci=max(dict_sci_sorted, key=dict_sci_sorted.get)
  max_lit=max(dict_lit_sorted, key=dict_lit_sorted.get)
  max_art=max(dict_art_sorted, key=dict_art_sorted.get)



  claves =  ["matematicas", "español","ciencias", "literatura", "arte"]
  valores = [ max_math,max_spa,max_sci,max_lit,max_art]

  diccionario = dict((zip(claves, valores)))



  return  diccionario, dict_art_sorted

estudiante1 = {'nombre': 'pablo', 'matematicas': 5.0, 'español': 5.0, 'ciencias': 4.5, 'literatura': 4.2, 'arte': 3.7}
estudiante2 = {'nombre': 'andres', 'matematicas': 2.1, 'español': 5.0, 'ciencias': 3.0, 'literatura': 4.1, 'arte': 3.5}
estudiante3 = {'nombre': 'daniela', 'matematicas': 5.0, 'español': 4.2, 'ciencias': 4.4, 'literatura': 3.5, 'arte': 3.7}
estudiante4 = {'nombre': 'pedro', 'matematicas': 3.2, 'español': 3.7, 'ciencias': 3.1, 'literatura': 4.7, 'arte': 3.4}
estudiante5 = {'nombre': 'maria', 'matematicas': 4.7, 'español': 4.2, 'ciencias': 4.5, 'literatura': 4.7, 'arte': 3.2}

print(mejor_de_cada_curso(estudiante1,estudiante2,estudiante3,estudiante4,estudiante5))
# Out:
# ({'matematicas': 'pablo', 'español': 'pablo', 'ciencias': 'pablo', 'literatura': 'pedro', 'arte': 'pablo'}, {'pablo': 3.7, 'daniela': 3.7, 'andres': 3.5, 'pedro': 3.4, 'maria': 3.2})
