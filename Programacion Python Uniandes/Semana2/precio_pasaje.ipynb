# %%
def calcular_precio_pasaje(temporada_alta: bool, compania: str,edad:int,estudiante:bool):
  precio = 5 # Millones de COP
  variaciones = 0
  seguro = False

  if compania == "ALAS":
    if temporada_alta:
      precio = precio*1.3
    else: # Corrected indentation
      if edad >= 18 and estudiante: # Changed 'estudiante' to 'estudiante' to match function parameter
        precio = precio*(0.9)
  elif compania == "VOLAR":
    if temporada_alta:
      precio = precio*1.2
    if edad > 60:
      precio = precio + 0.1
  if edad < 18:
    precio = precio*0.5
  return precio # Corrected indentation

print(calcular_precio_pasaje(True, "ALAS",12,True)) # Corrected missing parentheses and 'ALAS' to "ALAS"
# Out:
# 3.25
