# %%
def clasificar_regalo(id:int):

  palindromo = False
  even = False

  if (id//100 == id % 10):
    palindromo = True

  if (id % 2 == 0):
    even = True

  if palindromo == True and even == True:
    answer = "boy"

  if palindromo == True and even == False:
    answer = "girl"

  if palindromo == False and even == True:
    answer = "man"

  if palindromo == False and even == False:
    answer = "woman"

  return answer

ID = int(input("Ingrese el ID del regalo: "))
print(clasificar_regalo(ID))
# Out:
# Ingrese el ID del regalo: 151
# girl
