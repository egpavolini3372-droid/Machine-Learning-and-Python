# %%
def suma_vectorial(vector_1:tuple,vector_2:tuple)->tuple:
  coordi1 = 0
  coordi2 = 0

  suma = (vector_1[0] + vector_2[0], vector_1[1] + vector_2[1], vector_1[2] + vector_2[2])

  return suma

vector1 = (1,4,5)
vector2 = (7,4,3)

print(suma_vectorial(vector1,vector2))
# Out:
# (8, 8, 8)
