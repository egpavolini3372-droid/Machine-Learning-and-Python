# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

categorias = ["Producto A","Producto B", "Producto C"]
sales = [120,150,90]

# Creación de gráficas verticales

plt.bar(categorias, sales, color="skyblue", label ="Ventas mensuales")

# Anotación con flecha para destacar un punto específico
plt.annotate("Maximo de Ventas", xy =("Producto B",150), xytext =("Producto C", 160) ,arrowprops=dict(facecolor = "black", shrink = 0.02 ))

plt.title("Ventas Mensuales por Producto")
plt.xlabel("Productos")
plt.ylabel("Ventas")

#plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

categorias = ["Producto A","Producto B", "Producto C"]
sales = [120,150,90]

# Creación de gráficas verticales

plt.barh(categorias,sales, color="skyblue", label ="Ventas mensuales")


plt.title("Ventas Mensuales por Producto")
plt.xlabel("Productos")
plt.ylabel("Ventas")

#plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

products = ["Producto A","Producto B", "Producto C"]
Market_share = [50,35,15]

plt.pie(Market_share, labels=products, autopct="%1.1f%%",startangle=45, colors=["gold","lightcoral","orange"] )

plt.title("Participacion de Mercado por producto")

plt.axis("equal")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.normal(165, 15, 1000)
print(data)

plt.figure(figsize=(8,6))
# Out:
# [157.64830441 161.14961349 159.36750917 170.6895561  169.93476237
#  160.09938443 166.65251036 169.48014611 173.40970366 159.33582151
#  172.36982016 158.53657961 170.22420571 159.71591273 170.9400813
#  167.89358014 169.52784724 167.79109207 162.0172165  166.42178212
#  163.01593803 160.99050993 169.30192848 166.68705399 173.71067818
#  166.97735194 165.68731212 161.69468679 161.14980817 159.72621808
#  168.31387915 165.96583375 166.86009701 169.83613901 169.29071284
#  161.54063693 168.99440472 164.68375127 161.99853591 164.06624131
#  162.52432654 175.90101399 170.27226165 166.93719194 163.82504207
#  164.66854904 161.383261   165.0358071  158.99223249 167.99764883
#  158.83110811 165.5522145  156.75587443 162.65952347 166.81966961
#  163.03433954 165.13131725 162.96937733 167.01535177 167.60722707
#  173.49683145 164.95452918 164.07075987 169.97308633 159.01830416
#  166.96456624 167.43354954 166.60799923 161.83025748 164.54489825
# ...
